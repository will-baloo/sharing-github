# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Create a list to append all tweet attributes(data)
attributes_container = []

# %%
# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:elonmusk').get_items()):
    if i>100:
        break
    attributes_container.append([tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.rawContent, tweet.mentionedUsers])

# %%
# Creating a dataframe from the tweets list above 
tweets_df = pd.DataFrame(attributes_container, columns=["Date Created", "Number of Likes", "Source of Tweet", "Tweets","Mentioned Users"])

# %%
tweets_df.head(50)
# Out:
#                 Date Created  Number of Likes     Source of Tweet  \
# 0  2023-01-17 02:02:45+00:00             1841  Twitter for iPhone
# 1  2023-01-16 22:16:42+00:00             2143  Twitter for iPhone
# 2  2023-01-16 20:07:25+00:00              947  Twitter for iPhone
# 3  2023-01-16 19:56:29+00:00             4970  Twitter for iPhone
# 4  2023-01-16 19:36:23+00:00            11636  Twitter for iPhone
# 5  2023-01-16 19:25:23+00:00             9625  Twitter for iPhone
# 6  2023-01-16 19:11:25+00:00             5414  Twitter for iPhone
# 7  2023-01-16 18:55:41+00:00            20368  Twitter for iPhone
# 8  2023-01-16 17:44:47+00:00            20149  Twitter for iPhone
# 9  2023-01-16 05:11:57+00:00            63242  Twitter for iPhone
# 10 2023-01-16 05:06:21+00:00           111835  Twitter for iPhone
# 11 2023-01-16 05:01:37+00:00            16387  Twitter for iPhone
# 12 2023-01-16 04:59:45+00:00             6922  Twitter for iPhone
# ...

# %%
tweets_df["Usernames"] = tweets_df["Mentioned Users"].apply(lambda x: None if x ==  None else len(x))

# %%
tweets_df["Likes Threshold"] = tweets_df["Number of Likes"].apply(lambda x: True if x > 10000 else False )
